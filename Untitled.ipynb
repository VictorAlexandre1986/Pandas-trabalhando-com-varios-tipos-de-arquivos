# %%
import pandas as pd

# %%
arquivo = "superstore_data.csv"

# %%
data_frame = pd.read_csv(arquivo)

# %%
data_frame.head(10)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
# 5   7348        1958         PhD         Single  71691.0        0         0
# 6   4073        1954    2n Cycle        Married  63564.0        0         0
# 7   1991        1967  Graduation       Together  44931.0        0         1
# 8   4047        1954         PhD        Married  65324.0        0         1
# 9   9477        1954         PhD        Married  65324.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
#Lendo um arquivo csv separado por ponto e virgula

arquivo2 = "superstore_data_ponto_virgula.csv"

data_frame2 = pd.read_csv(arquivo2, sep=";")

data_frame2.head(10)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
# 5   7348        1958         PhD         Single  71691.0        0         0
# 6   4073        1954    2n Cycle        Married  63564.0        0         0
# 7   1991        1967  Graduation       Together  44931.0        0         1
# 8   4047        1954         PhD        Married  65324.0        0         1
# 9   9477        1954         PhD        Married  65324.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
#As vezes pode dar um erro de encoding
#O erro de encoding ocorre quando a biblioteca Pandas não consegue interpretar corretamente os caracteres de um arquivo CSV.
#Para resolver esse erro, é necessário identificar a codificação correta do arquivo CSV e especificá-la ao carregar o arquivo 
#com a biblioteca Pandas.
#Nós podemos usar uma biblioteca chamada chardet para detectar o encoding de um arquivo CSV

import chardet

with open('superstore_data_ponto_virgula.csv', 'rb') as file:
    print(chardet.detect(file.read()))

#Lendo o arquivo csv especificando o tipo a coding utilizada
df = pd.read_csv('superstore_data_ponto_virgula.csv', encoding='ascii')
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
#Especificando o numero de linhas que deseja ler do arquivo

df1 = pd.read_csv('superstore_data_ponto_virgula.csv', nrows=10, sep=";")
df1
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
# 5   7348        1958         PhD         Single   71691        0         0
# 6   4073        1954    2n Cycle        Married   63564        0         0
# 7   1991        1967  Graduation       Together   44931        0         1
# 8   4047        1954         PhD        Married   65324        0         1
# 9   9477        1954         PhD        Married   65324        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
#Lendo um arquivo csv e selecionando algumas colunas especificas no carregamento
df = pd.read_csv('superstore_data_ponto_virgula.csv', sep=";", usecols=['Id','Year_Birth','Income'])
df
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
#Salvando o data_frame em um arquivo csv, se salvar sem passar o index com False será duplicado o index na gravação
df.to_csv('arquivo_gerado.csv', index=False, sep=",")

# %%
#---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Ler os dados de planilhas

# %%
arquivo = 'emissoes_CO2.xlsx'

# %%
df = pd.read_excel(arquivo)

# %%
df.head(10)
# Out:
#           País ISO 3166-1 alpha-3     Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750.0    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751.0    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752.0    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753.0    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754.0    0.0     NaN   NaN  NaN      NaN
# 5  Afeganistão                AFG  1755.0    0.0     NaN   NaN  NaN      NaN
# 6  Afeganistão                AFG  1756.0    0.0     NaN   NaN  NaN      NaN
# 7  Afeganistão                AFG  1757.0    0.0     NaN   NaN  NaN      NaN
# 8  Afeganistão                AFG  1758.0    0.0     NaN   NaN  NaN      NaN
# 9  Afeganistão                AFG  1759.0    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# ...

# %%
#Verificando se o arquivo excel tem mais de uma pagina
pd.ExcelFile(arquivo).sheet_names
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
#É possivel ler os dados de uma pagina especifica informando seu nome o indice
#pd = pd.read_excel(arquivo, sheet_name=1)
df_fontes = pd.read_excel(arquivo, sheet_name='fontes')

# %%
df_fontes.head(10)
# Out:
#           País ISO 3166-1 alpha-3     Ano   Total  Carvão    Oléo     Gás  \
# 0  Afeganistão                AFG  1750.0  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afeganistão                AFG  1751.0  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afeganistão                AFG  1752.0  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afeganistão                AFG  1753.0  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afeganistão                AFG  1754.0  [NONE]  [NONE]  [NONE]  [NONE]
# 5  Afeganistão                AFG  1755.0  [NONE]  [NONE]  [NONE]  [NONE]
# 6  Afeganistão                AFG  1756.0  [NONE]  [NONE]  [NONE]  [NONE]
# 7  Afeganistão                AFG  1757.0  [NONE]  [NONE]  [NONE]  [NONE]
# 8  Afeganistão                AFG  1758.0  [NONE]  [NONE]  [NONE]  [NONE]
# 9  Afeganistão                AFG  1759.0  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cimento  Queima   Outro Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# ...

# %%
#É possivel especificar as colunas e o numero de linhas desejadas em um arquivo de excel
intervalo = pd.read_excel(arquivo, sheet_name="emissoes_C02", usecols='A:D', nrows=10)

# %%
intervalo
# Out:
#           País ISO 3166-1 alpha-3     Ano  Total
# 0  Afeganistão                AFG  1750.0    0.0
# 1  Afeganistão                AFG  1751.0    0.0
# 2  Afeganistão                AFG  1752.0    0.0
# 3  Afeganistão                AFG  1753.0    0.0
# 4  Afeganistão                AFG  1754.0    0.0
# 5  Afeganistão                AFG  1755.0    0.0
# 6  Afeganistão                AFG  1756.0    0.0
# 7  Afeganistão                AFG  1757.0    0.0
# 8  Afeganistão                AFG  1758.0    0.0
# 9  Afeganistão                AFG  1759.0    0.0

# %%
#Salvando o datarFrame em um arquivo excel
df_fontes.to_excel('fontes_CO2.xlsx', index=False)

# %%
#---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Lendo arquivos JSON

# %%
lista_pacientes = pd.read_json('pacientes.json')

# %%
lista_pacientes.head(10)
# Out:
#    ID_paciente Doenca_cardiaca    IMC Fumante Consumo_alcool  AVC  \
# 0            0             Nao  16.60     Sim            Nao  Nao
# 1            1             Nao  20.34     Nao            Nao  Sim
# 2            2             Nao  26.58     Sim            Nao  Nao
# 3            3             Nao  24.21     Nao            Nao  Nao
# 4            4             Nao  23.71     Nao            Nao  Nao
# 5            5             Sim  28.87     Sim            Nao  Nao
# 6            6             Nao  21.63     Nao            Nao  Nao
# 7            7             Nao  31.64     Sim            Nao  Nao
# 8            8             Nao  26.45     Nao            Nao  Nao
# 9            9             Nao  40.69     Nao            Nao  Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Sexo_biologico  \
# 0             3            30                  Nao       Feminino
# 1             0             0                  Nao       Feminino
# ...

# %%
#As vezes os qrquivos de um json podem estar aninhadas e sua exibicao no dataframe não sera correta
lista_pacientes_2 = pd.read_json('pacientes_2.json')

# %%
lista_pacientes_2.head(10)
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# 2  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_bi...
# 1  {'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_...
# 2  {'ID': '03', 'Faixa_etaria': '65-69', 'Sexo_bi...

# %%
#Normalizando os dados
df_normalizado = pd.json_normalize(lista_pacientes_2['Pacientes'])

# %%
df_normalizado.head()
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
df_normalizado.to_json('historico_pacientes_normalizado.json')

# %%
#---------------------------------------------------------------------------------------------------------------------------

# %%
# Buscando dados de paginas HTML
#Para isso vamos procurar por tabelas

dados_html = pd.read_html('filmes_wikipedia.html')
dados_html
# Out:
# [                                                    0  \
#  0                                                1998
#  1                                                1999
#  2                                                2000
#  3                                                2001
#  4                                                2002
#  5                                                2003
#  6                                                2004
#  7                                                2005
#  8                                                2005
#  9                                                2006
#  10                                               2006
#  11                                               2007
#  12                                               2008
#  13  .mw-parser-output .hlist dl,.mw-parser-output ...
#
#                                                      1
#  0                                          100 Movies
# ...

# %%
#O arquivo wikipedia possui 3 tabelas , nesse caso estamos selecionando a segunda tabela
top_filmes = dados_html[1]

# %%
top_filmes
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %%
#Salvando o dataframe em uma pagina html
top_filmes.to_html('top_filmes.html')

# %%
#-----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Ler arquivos XML

# %%
dados_imdb = pd.read_xml('imdb_top_1000.xml')

# %%
dados_imdb.head(5)
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# ...

# %%
#Salvando em um arquivo
dados_imdb.to_xml('Filmes.xml')

# %%
#-----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Trabalhando com Banco de dados

# %%
import sqlalchemy
from sqlalchemy import create_engine, MetaData, inspect, Table

# %%
#Criando o banco
engine = create_engine('sqlite:///:memory:')

# %%
dados = pd.read_csv('clientes_banco.csv')

# %%
dados.to_sql('clientes', engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12580/1847884073.py in <module>
# ----> 1 dados.to_sql('clientes', engine, index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ...

# %%
#Inspecionar o banco de dados
inspector = inspect(engine)

# %%
#Mostrando as tabelas do banco
print(inspector.get_table_names())
# Out:
# ['clientes']

# %%
query = 'SELECT * FROM clientes WHERE Categoria_de_renda = "Empregado"'

# %%
#Lendo os dados do banco de uma consulta
empregados = pd.read_sql(query, engine)

# %%
empregados
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
#Gravar dados no banco
empregados.to_sql('empregados', con=engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12580/1078744085.py in <module>
#       1 #Gravar dados no banco
# ----> 2 empregados.to_sql('empregados', con=engine, index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ...

# %%
#Lendo a tabela 
pd.read_sql_table('empregados', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
pd.read_sql_table('empregados', engine, columns=['ID_Cliente','Grau_escolaridade','Rendimento_anual'])
# Out:
#         ID_Cliente Grau_escolaridade  Rendimento_anual
# 0          5008804   Ensino superior          427500.0
# 1          5008805   Ensino superior          427500.0
# 2          5008806      Ensino médio          112500.0
# 3          5008815   Ensino superior          270000.0
# 4          5112956   Ensino superior          270000.0
# ...            ...               ...               ...
# 226054     6837905      Ensino médio          355050.0
# 226055     6837906      Ensino médio          355050.0
# 226056     6839936      Ensino médio          135000.0
# 226057     6840222      Ensino médio          103500.0
# 226058     6842885      Ensino médio          121500.0
#
# [226059 rows x 3 columns]

# %%
#Atualizando os dados do banco
query = 'SELECT * FROM clientes ;'

pd.read_sql(query, engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
query = 'DELETE FROM clientes WHERE ID_Cliente=5008804'
with engine.connect() as conn:
    conn.execute(query)

# %%
#Primeiro registro excluido
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008805     32   Ensino superior  União-estável                2
# 1          5008806     58      Ensino médio         Casado                2
# 2          5008808     52      Ensino médio       Solteiro                1
# 3          5008809     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
#Atualizando um registro
query = "UPDATE clientes SET Grau_escolaridade='Ensino superior' WHERE ID_Cliente=5008808"
with engine.connect() as conn:
    conn.execute(query)

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008805     32   Ensino superior  União-estável                2
# 1          5008806     58      Ensino médio         Casado                2
# 2          5008808     52   Ensino superior       Solteiro                1
# 3          5008809     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...
